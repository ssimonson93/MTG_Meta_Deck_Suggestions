# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import re

# %%
supported_formats = {
    'standard': 'format?f=ST',
    'pioneer': 'format?f=PI',
    'modern': 'format?f=MO',
    'legacy': 'format?f=LE',
    'historic': 'format?f=HI',
    'vintage': 'format?f=VI',  # low ammount of data
    'pauper': 'format?f=PAU'  # literally 1 tier list, moatly for test purposes
}

# %%
url = 'https://www.mtgtop8.com/'

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.width = 0
pd.options.display.max_colwidth = None

# %%
def get_tournament_links(mtg_format: str) -> pd.DataFrame:
    """
    Takes format name, return Pandas DataFrame with link to tier list for each month that is available on mtgtop8.com
    :param str mtg_format: one of the supported formats
    :return: pd.DataDrame with links to each tier list
    """

    mtg_format = mtg_format.lower()  # make input lower case
    if mtg_format in supported_formats:
        format_url = supported_formats[mtg_format]
    else:
        raise Exception('Format not on the list of formats: ', mtg_format)

    full_url = url + format_url
    time.sleep(random.randint(0, 3))
    page = requests.get(full_url)  # get the page
    soup = BeautifulSoup(page.content, "html.parser")  # get only it's content
#     tournament_element = soup.find(style="class: 'stable'")  # search for tournament list
    tourney_links = soup.find_all('a', attrs={'href': re.compile("event")})  # get all the tournament links
    tournament_link = []

    for element in tourney_links:
            tournament_link.append(url+element['href'])  # link to decks of that tournament

    tournament_link = list(set(tournament_link))
    tournament_links = pd.DataFrame(columns=['link to tournament'])
    tournament_links['link to tournament']= tournament_link
#     print(tournament_links)
    return tournament_links

# %%
# get_tournament_links("modern")

# %%
def get_deck_links_tournament(tournament_url: str) -> pd.DataFrame:
    """
    Given a URL for a tournament scrapes all deck links in that tournaent
    :param str tournament_url: string that is a link to a tournament
    :return: pd.DataFrame with links to all decks on that page
    """
    time.sleep(random.randint(0, 3))
    page = requests.get(tournament_url)  # get the page
    soup = BeautifulSoup(page.content, "html.parser")  # get only it's content
    # this is spaghetti but the website is also spaghetti
#     print(soup)
    searching_by_style = soup.find_all(style='margin:0px 4px 0px 4px;')
#     print(searching_by_style)
    decks = []
    Deck_link = ""
    for element in searching_by_style:  # it should be exactly 1 iteration any ways
        aas = element.find_all('a')
#         print(aas[0]) 
#         hrefs = [x.find_all(href=True) for x in aas]
        strings = [str(x) for x in aas]
#         print(strings);
        for element in strings:
            if r'?e' in element:
#                 print(element)
                regex_1 = '<a href="'
                regex_2 = '\".*$'
                
                deck_link_1 = re.sub(regex_1,"", element)
                deck_link = re.sub(regex_2,"", deck_link_1)
#                 print(deck_link)
                full_deck_link = url + 'event' + deck_link
                full_deck_link = full_deck_link.replace("amp;","")
#                 print(full_deck_link)
                decks.append(full_deck_link)
#                 print(decks)
    decks = list(set(decks))
#     print(decks)
#         for index, tr in enumerate(trs):
# #             print('Tier ' + str(rank))
#             aas = all_links = tr.find_all('a')  # Find all links
#             deck_link = ""
#             x = iter(aas)
#             if len(aas) % 3 != 0:
#                 raise Exception("Number of links isn't devideable by zero (something went wrong!)")
#             for a_1, a_2, a_3 in zip(x, x, x):
#                 try:
#                     deck_link = a_2['href']
#                     # print(tier, deck_name, deck_link, deck_author)
#                     full_deck_link = url + 'event' + deck_link
#                     decks.append([full_deck_link])
#                 except IndexError:
#                     print('Likely no deck link and author, only picture!')
#                     print(a_1, a_2, a_3)
    
    decks_df = pd.DataFrame({'Deck link': decks})
#     print(decks_df)
    return decks_df

# %%
# get_deck_links_tournament("https://www.mtgtop8.com/event?e=39400&f=MO")

# %%
def get_deck_links_all(mtg_format: str) -> pd.DataFrame:
    """
    Get all decks from "decks to beat" for a given format.
    :param str mtg_format: one of the supported formats
    :return: pd.DataFrame with the month, tier, link to the deck and other data
    """

    mtg_format = mtg_format.lower()  # make input lower case
    if mtg_format not in supported_formats:
        raise Exception('Format not on the list of formats: ', mtg_format)

    tier_lists = get_tournament_links(mtg_format)
#     all_decks_from_format = pd.DataFrame(columns=
#                                          ['Year', 'Month', 'rank', 'Name', 'Author name', 'Deck link'])
#     year = []
#     month = []
#     rank = []
#     name = []
#     author_name = []
#     deck_link = []
    all_decks_from_format = pd.DataFrame(columns=
                                         ['Deck link'])
    deck_link = []
#     tier_lists = tier_lists.values.astype({'link to tournament':'string'})
#     print(tier_lists)
#     for index,row in tier_lists.iterrows():       
#         decks_from_tournament = get_deck_links_tournament()
#         for index, row in decks_from_tournament.iterrows():
#             deck_link.append(['Deck link'])
    for index, row in tier_lists.iterrows():
        deck_from_tournament = get_deck_links_tournament(row['link to tournament'])                
#         print('Adding', ': ', row['Month'], '.', row['Year'], sep='')
        for index2, row2 in deck_from_tournament.iterrows():
#             year.append(row['Year'])
#             month.append(row['Month'])
#             tier.append(row2['rank'])
#             name.append(row2['Name'])
#             author_name.append(row2['Author name'])
            deck_link.append(row2['Deck link'])
#             print(deck_link)

#     all_decks_from_format['Year'] = year
#     all_decks_from_format['Month'] = month
#     all_decks_from_format['Rank'] = rank
#     all_decks_from_format['Name'] = name
#     all_decks_from_format['Author name'] = author_name
    all_decks_from_format['Deck link'] = deck_link
    return all_decks_from_format

# %%
# get_deck_links_all("legacy")

# %%
# def get_deck_links_all(mtg_format: str) -> pd.DataFrame:
#     """
#     Get all decks from "decks to beat" for a given format.
#     :param str mtg_format: one of the supported formats
#     :return: pd.DataFrame with the month, tier, link to the deck and other data
#     """

#     mtg_format = mtg_format.lower()  # make input lower case
#     if mtg_format not in supported_formats:
#         raise Exception('Format not on the list of formats: ', mtg_format)
#     tournament_links = get_tournament_links('link to tournament')
# #     all_decks_from_format = pd.DataFrame(columns=
# #                                          ['Year', 'Month', 'rank', 'Name', 'Author name', 'Deck link'])
# #     year = []
# #     month = []
# #     rank = []
# #     name = []
# #     author_name = []
# #     deck_link = []
#     all_decks_from_format = pd.DataFrame(columns=
#                                          ['Deck link'])
#     deck_link = []
#     for index, row in tournament_lists.iterrows():
# #         print('Adding', ': ', row['Month'], '.', row['Year'], sep='')
# #             for index2, row2 in deck_from_month.iterrows():
# #             year.append(row['Year'])
# #             month.append(row['Month'])
# #             tier.append(row2['rank'])
# #             name.append(row2['Name'])
# #             author_name.append(row2['Author name'])
#         deck_link.append(['Deck link'])

# #     all_decks_from_format['Year'] = year
# #     all_decks_from_format['Month'] = month
# #     all_decks_from_format['Rank'] = rank
# #     all_decks_from_format['Name'] = name
# #     all_decks_from_format['Author name'] = author_name
#     all_decks_from_format['Deck link'] = deck_link
#     print(all_decks_from_format)
#     return all_decks_from_format

# %%
def get_deck_list(deck_link: str) -> str:
    """
    Scrape deck list from provided deck link
    :param str deck_link: deck link to mtgtop8.com
    :return: deck list as string
    """

    time.sleep(random.randint(0, 3))
    page = requests.get(deck_link)
    soup = BeautifulSoup(page.content, "html.parser")  # get only it's content
    found_element = soup.find_all('a', {'href': re.compile(r'mtgo')})
#     print(found_element)
    if len(found_element) == 2:
        found_element.pop(0)
        mtgo_url = found_element[0]['href']
        full_url = url + mtgo_url
        print(full_url)
        time.sleep(random.randint(0, 3))
        page = requests.get(full_url)  # get the *.txt file on the website containing deck list in MTGO format
        deck_list = page.text
        return deck_list
    elif len(found_element) == 0:
        print(deck_link + " gave an error")
    else:
        mtgo_url = found_element[0]['href']
        full_url = url + mtgo_url
        print(full_url)
        time.sleep(random.randint(0, 3))
        page = requests.get(full_url)  # get the *.txt file on the website containing deck list in MTGO format
        deck_list = page.text
        return deck_list

# %%
# get_deck_list("https://www.mtgtop8.com/event?e=39428&d=493595&f=LE")

# %%
def get_all_decklists(mtg_format: str) -> pd.DataFrame:
    """
    Given a format returns a DataFrame with information about all decks, including deck lists
    :param str mtg_format: one of the supported formats
    :return: pd.Dataframe with deck lists and other information
    """

    deck_strings = []
    counter = 1
    all_deck_lists = get_deck_links_all(mtg_format)
    print("\nTotal decklists found:", len(all_deck_lists))
    for index, row in all_deck_lists.iterrows():
        deck_list = get_deck_list(row['Deck link'])  # get the decklist to string format from its web page
        # noinspection PyTypeChecker
        deck_strings.append(deck_list)
        print(str(counter) + ' decks done')
        counter += 1
    all_deck_lists['Deck list'] = deck_strings
    print(all_deck_lists)

    return all_deck_lists

# %%
# get_deck_list('https://www.mtgtop8.com/event?e=38037&d=484549&f=MO')
format_to_scrape = 'vintage'
print('getting all ' + (format_to_scrape) + " decks")
df_to_save = get_all_decklists(format_to_scrape)
df_to_save.to_csv(path_or_buf=str(format_to_scrape + " decks.csv"), index=False)
# Out:
# getting all vintage decks
#
# Total decklists found: 164
# https://www.mtgtop8.com/mtgo?d=490465&f=Vintage_Dimir_Control_by_Daniele_Masi
# 1 decks done
# https://www.mtgtop8.com/mtgo?d=490463&f=Vintage_Paradoxical_by_Davide_Rosadini
# 2 decks done
# https://www.mtgtop8.com/mtgo?d=490464&f=Vintage_Mentor_Paradoxical_by_David_Cioffini
# 3 decks done
# https://www.mtgtop8.com/mtgo?d=490466&f=Vintage_Golos_MUD_by_Tommaso_Pacini
# 4 decks done
# https://www.mtgtop8.com/mtgo?d=490384&f=Vintage_Selesnya_Hatebear_by_Wesal
# 5 decks done
# https://www.mtgtop8.com/mtgo?d=490388&f=Vintage_Grixis_Control_by_discoverN
# 6 decks done
# https://www.mtgtop8.com/mtgo?d=490382&f=Vintage_Grixis_Control_by_handsomePPZ
# 7 decks done
# https://www.mtgtop8.com/mtgo?d=490383&f=Vintage_Merfolk_by_Mogged
# 8 decks done
# https://www.mtgtop8.com/mtgo?d=490386&f=Vintage_Grixis_Control_by_KingHairy
# 9 decks done
# https://www.mtgtop8.com/mtgo?d=490385&f=Vintage_Paradoxical_Storm_by_RespectTheCat
# 10 decks done
# https://www.mtgtop8.com/mtgo?d=490381&f=Vintage_Underworld_Breach_by_duke12
# 11 decks done
# https://www.mtgtop8.com/mtgo?d=490387&f=Vintage_Bazaar_Aggro_by_otakkun
# 12 decks done
# https://www.mtgtop8.com/mtgo?d=492483&f=Vintage_Golos_Shops_by_Sean_Soderman
# 13 decks done
# https://www.mtgtop8.com/mtgo?d=492481&f=Vintage_Jeskai_Xerox_by_Brian_Tweedy
# 14 decks done
# https://www.mtgtop8.com/mtgo?d=492482&f=Vintage_Oops_All_Spells_by_Patrick_Vincent
# 15 decks done
# https://www.mtgtop8.com/mtgo?d=492480&f=Vintage_Ur_Initiative_by_Bryan_Hockey
# 16 decks done
# https://www.mtgtop8.com/mtgo?d=492731&f=Vintage_Mentor_Paradoxical_by_mourning_palace
# 17 decks done
# https://www.mtgtop8.com/mtgo?d=492732&f=Vintage_UR_Aggro_by_CodeProvider
# 18 decks done
# https://www.mtgtop8.com/mtgo?d=492735&f=Vintage_Dredge_by_NARTHAN
# 19 decks done
# https://www.mtgtop8.com/mtgo?d=492736&f=Vintage_Bazaar_Aggro_by_NathanLipetz
# 20 decks done
# https://www.mtgtop8.com/mtgo?d=492733&f=Vintage_UR_Aggro_by_trinity
# 21 decks done
# https://www.mtgtop8.com/mtgo?d=492734&f=Vintage_Paradoxical_Storm_by_CapTenPlanIt
# 22 decks done
# https://www.mtgtop8.com/mtgo?d=493867&f=Vintage_Polymorph_by_AntiRush
# 23 decks done
# https://www.mtgtop8.com/mtgo?d=493871&f=Vintage_Golos_MUD_by_ConradKolos
# 24 decks done
# https://www.mtgtop8.com/mtgo?d=493870&f=Vintage_Doomsday_by_MissClique
# 25 decks done
# https://www.mtgtop8.com/mtgo?d=493872&f=Vintage_Bazaar_Aggro_by_HanktheObese
# 26 decks done
# https://www.mtgtop8.com/mtgo?d=493868&f=Vintage_Oath_of_Druids_by_Wanjia
# 27 decks done
# https://www.mtgtop8.com/mtgo?d=493869&f=Vintage_Painter_by_FGC
# 28 decks done
# https://www.mtgtop8.com/mtgo?d=493865&f=Vintage_Oath_of_Druids_by_CodeProvider
# 29 decks done
# https://www.mtgtop8.com/mtgo?d=493866&f=Vintage_Bazaar_Aggro_by_geekyjackson
# 30 decks done
# https://www.mtgtop8.com/mtgo?d=490374&f=Vintage_Grixis_Control_by_handsomePPZ
# 31 decks done
# https://www.mtgtop8.com/mtgo?d=490378&f=Vintage_Doomsday_by_Enrichetta
# 32 decks done
# https://www.mtgtop8.com/mtgo?d=490379&f=Vintage_Underworld_Breach_by_Kinarus
# 33 decks done
# https://www.mtgtop8.com/mtgo?d=490377&f=Vintage_Oath_of_Druids_by_Miharu_Fuyumiya
# 34 decks done
# https://www.mtgtop8.com/mtgo?d=490380&f=Vintage_Oath_of_Druids_by_ChainsOfMephiStopPlz
# 35 decks done
# https://www.mtgtop8.com/mtgo?d=490376&f=Vintage_Jeskai_Xerox_by_unluckymonkey
# 36 decks done
# https://www.mtgtop8.com/mtgo?d=490373&f=Vintage_Bazaar_Aggro_by_Firetruck
# 37 decks done
# https://www.mtgtop8.com/mtgo?d=490375&f=Vintage_Grixis_Control_by_AFX
# 38 decks done
# https://www.mtgtop8.com/mtgo?d=489886&f=Vintage_UR_Aggro_by_Mogged
# 39 decks done
# https://www.mtgtop8.com/mtgo?d=489881&f=Vintage_Planeswalker_Control_by_CodeProvider
# 40 decks done
# https://www.mtgtop8.com/mtgo?d=489887&f=Vintage_Golos_MUD_by_Tsubasa_Cat
# 41 decks done
# https://www.mtgtop8.com/mtgo?d=489884&f=Vintage_Dragon_Stompy_by_TeamLeaderNA
# 42 decks done
# https://www.mtgtop8.com/mtgo?d=489885&f=Vintage_Grixis_Control_by_AFX
# 43 decks done
# https://www.mtgtop8.com/mtgo?d=489883&f=Vintage_Golos_MUD_by_NorrathDecay
# 44 decks done
# https://www.mtgtop8.com/mtgo?d=489882&f=Vintage_BUG_Midrange_by_musasabi
# 45 decks done
# https://www.mtgtop8.com/mtgo?d=489888&f=Vintage_Jeskai_Xerox_by_unluckymonkey
# 46 decks done
# https://www.mtgtop8.com/mtgo?d=491568&f=Vintage_Dragon_Stompy_by_Giuseppe_Di_Vincenzo
# 47 decks done
# https://www.mtgtop8.com/mtgo?d=491566&f=Vintage_Bazaar_by_Fabio_Zanasi_
# 48 decks done
# https://www.mtgtop8.com/mtgo?d=491569&f=Vintage_Mud_by_Attilio_Bragantino
# 49 decks done
# https://www.mtgtop8.com/mtgo?d=491567&f=Vintage_Jeskai_Control_by_Raffaele_Ramagli
# 50 decks done
# https://www.mtgtop8.com/mtgo?d=485605&f=Vintage_Jeskai_Xerox_by_NooxTom
# 51 decks done
# https://www.mtgtop8.com/mtgo?d=485608&f=Vintage_Grixis_Control_by_Butakov
# 52 decks done
# https://www.mtgtop8.com/mtgo?d=485604&f=Vintage_Esper_Control_by_MentalMisstep
# 53 decks done
# https://www.mtgtop8.com/mtgo?d=485607&f=Vintage_Grixis_Control_by_Rooney56
# 54 decks done
# https://www.mtgtop8.com/mtgo?d=485606&f=Vintage_Dredge_by_Lord_Beerus
# 55 decks done
# https://www.mtgtop8.com/mtgo?d=485610&f=Vintage_Bazaar_Aggro_by_Slatorade
# 56 decks done
# https://www.mtgtop8.com/mtgo?d=485611&f=Vintage_Jeskai_Xerox_by_Oceansoul92
# 57 decks done
# https://www.mtgtop8.com/mtgo?d=485609&f=Vintage_Mentor_Paradoxical_by_Cioffo86
# 58 decks done
# https://www.mtgtop8.com/mtgo?d=493826&f=Vintage_Grixis_Control_by_KingHairy
# 59 decks done
# https://www.mtgtop8.com/mtgo?d=493823&f=Vintage_Golos_MUD_by_416FrowningTable
# 60 decks done
# https://www.mtgtop8.com/mtgo?d=493827&f=Vintage_Landless_Spy_by_medvedev
# 61 decks done
# https://www.mtgtop8.com/mtgo?d=493821&f=Vintage_Esper_Paradoxical_by_Clamavus
# 62 decks done
# https://www.mtgtop8.com/mtgo?d=493822&f=Vintage_Eldrazi_W_by_Wesal
# 63 decks done
# https://www.mtgtop8.com/mtgo?d=493820&f=Vintage_Underworld_Breach_by_Tsubasa_Cat
# 64 decks done
# https://www.mtgtop8.com/mtgo?d=493824&f=Vintage_BUG_Midrange_by_MadMaxErnst
# 65 decks done
# https://www.mtgtop8.com/mtgo?d=493825&f=Vintage_Golos_MUD_by__Shatun_
# 66 decks done
# https://www.mtgtop8.com/mtgo?d=493766&f=Vintage_Underworld_Breach_by_duke12
# 67 decks done
# https://www.mtgtop8.com/mtgo?d=493759&f=Vintage_Underworld_Breach_by_Kinarus
# 68 decks done
# https://www.mtgtop8.com/mtgo?d=493765&f=Vintage_Bazaar_Aggro_by_bless_von
# 69 decks done
# https://www.mtgtop8.com/mtgo?d=493764&f=Vintage_Underworld_Breach_by_twinlesstwin
# 70 decks done
# https://www.mtgtop8.com/mtgo?d=493763&f=Vintage_Hatebear_by_grymn
# 71 decks done
# https://www.mtgtop8.com/mtgo?d=493762&f=Vintage_Bazaar_Aggro_by_Montolio
# 72 decks done
# https://www.mtgtop8.com/mtgo?d=493761&f=Vintage_BUG_Midrange_by_dancingjesus191
# 73 decks done
# https://www.mtgtop8.com/mtgo?d=493760&f=Vintage_Jeskai_Xerox_by_tom_basketball
# 74 decks done
# https://www.mtgtop8.com/mtgo?d=488782&f=Vintage_Paradoxical_Storm_by_RespectTheCat
# 75 decks done
# https://www.mtgtop8.com/mtgo?d=488776&f=Vintage_Grixis_Control_by_kasa
# 76 decks done
# https://www.mtgtop8.com/mtgo?d=488779&f=Vintage_Planeswalker_Control_by_Dazai
# 77 decks done
# https://www.mtgtop8.com/mtgo?d=488780&f=Vintage_Grixis_Control_by_zhinonono
# 78 decks done
# https://www.mtgtop8.com/mtgo?d=488778&f=Vintage_UR_Aggro_by_jaredallsop619
# 79 decks done
# https://www.mtgtop8.com/mtgo?d=488783&f=Vintage_Underworld_Breach_by_HouseOfManaMTG
# 80 decks done
# https://www.mtgtop8.com/mtgo?d=488781&f=Vintage_Doomsday_by_Wyjx
# 81 decks done
# https://www.mtgtop8.com/mtgo?d=488777&f=Vintage_Bazaar_Aggro_by_hopeof130
# 82 decks done
# https://www.mtgtop8.com/mtgo?d=481476&f=Vintage_Coveted_Jewel_Paradoxical_by_Andrew_Higganbotham
# 83 decks done
# https://www.mtgtop8.com/mtgo?d=481480&f=Vintage_Goblins_by_Robin_Mannas
# 84 decks done
# https://www.mtgtop8.com/mtgo?d=481481&f=Vintage_Paradoxical_by_Nick_Dijohn
# 85 decks done
# https://www.mtgtop8.com/mtgo?d=481475&f=Vintage_Bug_Midrange_by_Joe_Brennan
# 86 decks done
# https://www.mtgtop8.com/mtgo?d=481477&f=Vintage_Breach_by_Edward_Bonar_Ii
# 87 decks done
# https://www.mtgtop8.com/mtgo?d=481479&f=Vintage_Paradoxical_by_Dan_Miller
# 88 decks done
# https://www.mtgtop8.com/mtgo?d=481478&f=Vintage_Esper_Tinker_by_Curtis_Thompson
# 89 decks done
# https://www.mtgtop8.com/mtgo?d=481482&f=Vintage_Bug_Midrange_by_Stephen_Harvey
# 90 decks done
# https://www.mtgtop8.com/mtgo?d=491131&f=Vintage_Planeswalker_Control_by_ZollZollZoll
# 91 decks done
# https://www.mtgtop8.com/mtgo?d=491125&f=Vintage_Bazaar_Aggro_by_Firetruck
# 92 decks done
# https://www.mtgtop8.com/mtgo?d=491132&f=Vintage_Grixis_Control_by_mosh110
# 93 decks done
# https://www.mtgtop8.com/mtgo?d=491127&f=Vintage_Bazaar_Aggro_by_Hitogoroshi80
# 94 decks done
# https://www.mtgtop8.com/mtgo?d=491128&f=Vintage_Dredge_by_TheSleepingEye
# 95 decks done
# https://www.mtgtop8.com/mtgo?d=491130&f=Vintage_Hatebear_by_wizardwand
# 96 decks done
# https://www.mtgtop8.com/mtgo?d=491126&f=Vintage_Jund_by_Absorbentthree
# 97 decks done
# https://www.mtgtop8.com/mtgo?d=491129&f=Vintage_Oath_of_Druids_by_IfHeDiesHeDies
# 98 decks done
# https://www.mtgtop8.com/mtgo?d=490302&f=Vintage_Bazaar_Aggro_by_IamActuallyLvL1
# 99 decks done
# https://www.mtgtop8.com/mtgo?d=490301&f=Vintage_Underworld_Breach_by_Phill_Hellmuth
# 100 decks done
# https://www.mtgtop8.com/mtgo?d=490303&f=Vintage_Underworld_Breach_by_Kinarus
# 101 decks done
# https://www.mtgtop8.com/mtgo?d=490300&f=Vintage_Landless_Spy_by_sandydogmtg
# 102 decks done
# https://www.mtgtop8.com/mtgo?d=492964&f=Vintage_BUG_Midrange_by_IamActuallyLvL1
# 103 decks done
# https://www.mtgtop8.com/mtgo?d=492965&f=Vintage_Landless_Spy_by_sandydogmtg
# 104 decks done
# https://www.mtgtop8.com/mtgo?d=492966&f=Vintage_Oath_of_Druids_by_MisplayMcgee
# 105 decks done
# https://www.mtgtop8.com/mtgo?d=488920&f=Vintage_Esper_Tinker_by_Rachel_Feingersh
# 106 decks done
# https://www.mtgtop8.com/mtgo?d=488918&f=Vintage_Oath_by_Adam_Grosse
# 107 decks done
# https://www.mtgtop8.com/mtgo?d=488922&f=Vintage_Elves_by_Ryan_Fisher
# 108 decks done
# https://www.mtgtop8.com/mtgo?d=488921&f=Vintage_Doomsday_by_Hank_Zhong
# 109 decks done
# https://www.mtgtop8.com/mtgo?d=488917&f=Vintage_Shops_by_Mark_Hollaar
# 110 decks done
# https://www.mtgtop8.com/mtgo?d=488919&f=Vintage_Paradoxical_Outcome_by_Matt_Paquet
# 111 decks done
# https://www.mtgtop8.com/mtgo?d=488924&f=Vintage_Oath_by_William_Berry
# 112 decks done
# https://www.mtgtop8.com/mtgo?d=488923&f=Vintage_Grixis_Sheoldred_by_Jeremy_Pinter
# 113 decks done
# https://www.mtgtop8.com/mtgo?d=492078&f=Vintage_White_Trash_by_Oscar_Basart
# 114 decks done
# https://www.mtgtop8.com/mtgo?d=492079&f=Vintage_White_Trash_by_Tomàs_Winand
# 115 decks done
# https://www.mtgtop8.com/mtgo?d=492077&f=Vintage_4_Color_Midrange_by_Miquel_Alcoriza
# 116 decks done
# https://www.mtgtop8.com/mtgo?d=492080&f=Vintage_4_Color_Midrange_by_Mario_Fortes
# 117 decks done
# https://www.mtgtop8.com/mtgo?d=493347&f=Vintage_BUG_Midrange_by_AWepp
# 118 decks done
# https://www.mtgtop8.com/mtgo?d=493350&f=Vintage_Grixis_Control_by_LBBL
# 119 decks done
# https://www.mtgtop8.com/mtgo?d=493351&f=Vintage_Doomsday_by_Enrichetta
# 120 decks done
# https://www.mtgtop8.com/mtgo?d=493344&f=Vintage_BUG_Midrange_by_dancingjesus191
# 121 decks done
# https://www.mtgtop8.com/mtgo?d=493348&f=Vintage_Doomsday_by_Diem4x
# 122 decks done
# https://www.mtgtop8.com/mtgo?d=493345&f=Vintage_Bazaar_Aggro_by_toondoslav
# 123 decks done
# https://www.mtgtop8.com/mtgo?d=493349&f=Vintage_Bazaar_Aggro_by_helvetti
# 124 decks done
# https://www.mtgtop8.com/mtgo?d=493346&f=Vintage_Grixis_Control_by_ReneRandrup
# 125 decks done
# https://www.mtgtop8.com/mtgo?d=493753&f=Vintage_Landless_Spy_by_medvedev
# 126 decks done
# https://www.mtgtop8.com/mtgo?d=493758&f=Vintage_Oath_of_Druids_by_desolutionist
# 127 decks done
# https://www.mtgtop8.com/mtgo?d=493756&f=Vintage_Bug_Midrange_by_CodeProvider
# 128 decks done
# https://www.mtgtop8.com/mtgo?d=493751&f=Vintage_Paradoxical_Storm_by_jewdan
# 129 decks done
# https://www.mtgtop8.com/mtgo?d=493754&f=Vintage_Doomsday_by_FedericoIIMadao
# 130 decks done
# https://www.mtgtop8.com/mtgo?d=493757&f=Vintage_4c_Fish_by_unluckymonkey
# 131 decks done
# https://www.mtgtop8.com/mtgo?d=493755&f=Vintage_Planeswalker_Control_by_Boucha
# 132 decks done
# https://www.mtgtop8.com/mtgo?d=493752&f=Vintage_Paradoxical_by_s063
# 133 decks done
# https://www.mtgtop8.com/mtgo?d=488025&f=Vintage_Grixis_Control_by_Kobayashi_Tatsuumi
# 134 decks done
# https://www.mtgtop8.com/mtgo?d=488027&f=Vintage_Paradoxical_by_Tsumori_Youhei
# 135 decks done
# https://www.mtgtop8.com/mtgo?d=488030&f=Vintage_Dredge_by_Ichioka_Yand#363;ki
# 136 decks done
# https://www.mtgtop8.com/mtgo?d=488032&f=Vintage_Bazaar_Aggro_by_Morita_Susumu
# 137 decks done
# https://www.mtgtop8.com/mtgo?d=488028&f=Vintage_Grixis_Control_by_Meguro_Masahiko
# 138 decks done
# https://www.mtgtop8.com/mtgo?d=488029&f=Vintage_Doomsday_by_Suzuki_Yuto
# 139 decks done
# https://www.mtgtop8.com/mtgo?d=488031&f=Vintage_Oath_of_Druids_by_Kobayashi_Ryand#363;
# 140 decks done
# https://www.mtgtop8.com/mtgo?d=488026&f=Vintage_Landless_Spy_by_Suzuike_Fumiyasu
# 141 decks done
# https://www.mtgtop8.com/mtgo?d=493847&f=Vintage_Bazaar_Aggro_by_Kinarus
# 142 decks done
# https://www.mtgtop8.com/mtgo?d=493848&f=Vintage_MUD_by_ForsakenBalerion
# 143 decks done
# https://www.mtgtop8.com/mtgo?d=493846&f=Vintage_Bazaar_Aggro_by_bless_von
# 144 decks done
# https://www.mtgtop8.com/mtgo?d=493845&f=Vintage_Oath_of_Druids_by_MisplayMcgee
# 145 decks done
# https://www.mtgtop8.com/mtgo?d=492110&f=Vintage_Paradoxical_Outcome_by_Adrià_Romero
# 146 decks done
# https://www.mtgtop8.com/mtgo?d=492108&f=Vintage_Survival_Salad_by_Sergi_Hernández
# 147 decks done
# https://www.mtgtop8.com/mtgo?d=492109&f=Vintage_Temur_Midrange_by_Marc_Bertolín
# 148 decks done
# https://www.mtgtop8.com/mtgo?d=492107&f=Vintage_Dimir_Control_by_Mario_Fortes
# 149 decks done
# https://www.mtgtop8.com/mtgo?d=493773&f=Vintage_Landless_Spy_by_bgg88
# 150 decks done
# https://www.mtgtop8.com/mtgo?d=493770&f=Vintage_MUD_by_Montolio
# 151 decks done
# https://www.mtgtop8.com/mtgo?d=493772&f=Vintage_Underworld_Breach_by_Kinarus
# 152 decks done
# https://www.mtgtop8.com/mtgo?d=493767&f=Vintage_Paradoxical_by_bergamo83
# 153 decks done
# https://www.mtgtop8.com/mtgo?d=493769&f=Vintage_Dredge_by_Avaloon
# 154 decks done
# https://www.mtgtop8.com/mtgo?d=493771&f=Vintage_MUD_by_atlante
# 155 decks done
# https://www.mtgtop8.com/mtgo?d=493768&f=Vintage_Dredge_by_Breckoroni
# 156 decks done
# https://www.mtgtop8.com/mtgo?d=486109&f=Vintage_Paradoxical_Storm_by_Adam_Wasburn-moses
# 157 decks done
# https://www.mtgtop8.com/mtgo?d=486114&f=Vintage_Underworld_Breach_by_Tiziano_Ostigoni
# 158 decks done
# https://www.mtgtop8.com/mtgo?d=486115&f=Vintage_Pastrocchio_by_Aguanile87
# 159 decks done
# https://www.mtgtop8.com/mtgo?d=486112&f=Vintage_Doomsday_by_Francis_Cowper
# 160 decks done
# https://www.mtgtop8.com/mtgo?d=486113&f=Vintage_Underworld_Breach_by_Werther_Masi
# 161 decks done
# https://www.mtgtop8.com/mtgo?d=486108&f=Vintage_Mentor_Paradoxical_by_Cioffo86
# 162 decks done
# https://www.mtgtop8.com/mtgo?d=486111&f=Vintage_BUG_Midrange_by_Yannick_Jeths
# 163 decks done
# https://www.mtgtop8.com/mtgo?d=486110&f=Vintage_Meandeck_Jeskai_Wastelands_by_Raffaele_Ramagli
# 164 decks done
#                                                Deck link  \
# 0    https://www.mtgtop8.com/event?e=38941&d=490465&f=VI
# 1    https://www.mtgtop8.com/event?e=38941&d=490463&f=VI
# 2    https://www.mtgtop8.com/event?e=38941&d=490464&f=VI
# 3    https://www.mtgtop8.com/event?e=38941&d=490466&f=VI
# 4    https://www.mtgtop8.com/event?e=38926&d=490384&f=VI
# 5    https://www.mtgtop8.com/event?e=38926&d=490388&f=VI
# 6    https://www.mtgtop8.com/event?e=38926&d=490382&f=VI
# 7    https://www.mtgtop8.com/event?e=38926&d=490383&f=VI
# 8    https://www.mtgtop8.com/event?e=38926&d=490386&f=VI
# 9    https://www.mtgtop8.com/event?e=38926&d=490385&f=VI
# 10   https://www.mtgtop8.com/event?e=38926&d=490381&f=VI
# 11   https://www.mtgtop8.com/event?e=38926&d=490387&f=VI
# 12   https://www.mtgtop8.com/event?e=39272&d=492483&f=VI
# 13   https://www.mtgtop8.com/event?e=39272&d=492481&f=VI
# 14   https://www.mtgtop8.com/event?e=39272&d=492482&f=VI
# 15   https://www.mtgtop8.com/event?e=39272&d=492480&f=VI
# 16   https://www.mtgtop8.com/event?e=39314&d=492731&f=VI
# 17   https://www.mtgtop8.com/event?e=39314&d=492732&f=VI
# 18   https://www.mtgtop8.com/event?e=39314&d=492735&f=VI
# 19   https://www.mtgtop8.com/event?e=39314&d=492736&f=VI
# 20   https://www.mtgtop8.com/event?e=39314&d=492733&f=VI
# 21   https://www.mtgtop8.com/event?e=39314&d=492734&f=VI
# 22   https://www.mtgtop8.com/event?e=39461&d=493867&f=VI
# 23   https://www.mtgtop8.com/event?e=39461&d=493871&f=VI
# 24   https://www.mtgtop8.com/event?e=39461&d=493870&f=VI
# 25   https://www.mtgtop8.com/event?e=39461&d=493872&f=VI
# 26   https://www.mtgtop8.com/event?e=39461&d=493868&f=VI
# 27   https://www.mtgtop8.com/event?e=39461&d=493869&f=VI
# 28   https://www.mtgtop8.com/event?e=39461&d=493865&f=VI
# 29   https://www.mtgtop8.com/event?e=39461&d=493866&f=VI
# 30   https://www.mtgtop8.com/event?e=38925&d=490374&f=VI
# 31   https://www.mtgtop8.com/event?e=38925&d=490378&f=VI
# 32   https://www.mtgtop8.com/event?e=38925&d=490379&f=VI
# 33   https://www.mtgtop8.com/event?e=38925&d=490377&f=VI
# 34   https://www.mtgtop8.com/event?e=38925&d=490380&f=VI
# 35   https://www.mtgtop8.com/event?e=38925&d=490376&f=VI
# 36   https://www.mtgtop8.com/event?e=38925&d=490373&f=VI
# 37   https://www.mtgtop8.com/event?e=38925&d=490375&f=VI
# 38   https://www.mtgtop8.com/event?e=38848&d=489886&f=VI
# 39   https://www.mtgtop8.com/event?e=38848&d=489881&f=VI
# 40   https://www.mtgtop8.com/event?e=38848&d=489887&f=VI
# 41   https://www.mtgtop8.com/event?e=38848&d=489884&f=VI
# 42   https://www.mtgtop8.com/event?e=38848&d=489885&f=VI
# 43   https://www.mtgtop8.com/event?e=38848&d=489883&f=VI
# 44   https://www.mtgtop8.com/event?e=38848&d=489882&f=VI
# 45   https://www.mtgtop8.com/event?e=38848&d=489888&f=VI
# 46   https://www.mtgtop8.com/event?e=39114&d=491568&f=VI
# 47   https://www.mtgtop8.com/event?e=39114&d=491566&f=VI
# 48   https://www.mtgtop8.com/event?e=39114&d=491569&f=VI
# 49   https://www.mtgtop8.com/event?e=39114&d=491567&f=VI
# 50   https://www.mtgtop8.com/event?e=38202&d=485605&f=VI
# 51   https://www.mtgtop8.com/event?e=38202&d=485608&f=VI
# 52   https://www.mtgtop8.com/event?e=38202&d=485604&f=VI
# 53   https://www.mtgtop8.com/event?e=38202&d=485607&f=VI
# 54   https://www.mtgtop8.com/event?e=38202&d=485606&f=VI
# 55   https://www.mtgtop8.com/event?e=38202&d=485610&f=VI
# 56   https://www.mtgtop8.com/event?e=38202&d=485611&f=VI
# 57   https://www.mtgtop8.com/event?e=38202&d=485609&f=VI
# 58   https://www.mtgtop8.com/event?e=39453&d=493826&f=VI
# 59   https://www.mtgtop8.com/event?e=39453&d=493823&f=VI
# 60   https://www.mtgtop8.com/event?e=39453&d=493827&f=VI
# 61   https://www.mtgtop8.com/event?e=39453&d=493821&f=VI
# 62   https://www.mtgtop8.com/event?e=39453&d=493822&f=VI
# 63   https://www.mtgtop8.com/event?e=39453&d=493820&f=VI
# 64   https://www.mtgtop8.com/event?e=39453&d=493824&f=VI
# 65   https://www.mtgtop8.com/event?e=39453&d=493825&f=VI
# 66   https://www.mtgtop8.com/event?e=39444&d=493766&f=VI
# 67   https://www.mtgtop8.com/event?e=39444&d=493759&f=VI
# 68   https://www.mtgtop8.com/event?e=39444&d=493765&f=VI
# 69   https://www.mtgtop8.com/event?e=39444&d=493764&f=VI
# 70   https://www.mtgtop8.com/event?e=39444&d=493763&f=VI
# 71   https://www.mtgtop8.com/event?e=39444&d=493762&f=VI
# 72   https://www.mtgtop8.com/event?e=39444&d=493761&f=VI
# 73   https://www.mtgtop8.com/event?e=39444&d=493760&f=VI
# 74   https://www.mtgtop8.com/event?e=38684&d=488782&f=VI
# 75   https://www.mtgtop8.com/event?e=38684&d=488776&f=VI
# 76   https://www.mtgtop8.com/event?e=38684&d=488779&f=VI
# 77   https://www.mtgtop8.com/event?e=38684&d=488780&f=VI
# 78   https://www.mtgtop8.com/event?e=38684&d=488778&f=VI
# 79   https://www.mtgtop8.com/event?e=38684&d=488783&f=VI
# 80   https://www.mtgtop8.com/event?e=38684&d=488781&f=VI
# 81   https://www.mtgtop8.com/event?e=38684&d=488777&f=VI
# 82   https://www.mtgtop8.com/event?e=37563&d=481476&f=VI
# 83   https://www.mtgtop8.com/event?e=37563&d=481480&f=VI
# 84   https://www.mtgtop8.com/event?e=37563&d=481481&f=VI
# 85   https://www.mtgtop8.com/event?e=37563&d=481475&f=VI
# 86   https://www.mtgtop8.com/event?e=37563&d=481477&f=VI
# 87   https://www.mtgtop8.com/event?e=37563&d=481479&f=VI
# 88   https://www.mtgtop8.com/event?e=37563&d=481478&f=VI
# 89   https://www.mtgtop8.com/event?e=37563&d=481482&f=VI
# 90   https://www.mtgtop8.com/event?e=39049&d=491131&f=VI
# 91   https://www.mtgtop8.com/event?e=39049&d=491125&f=VI
# 92   https://www.mtgtop8.com/event?e=39049&d=491132&f=VI
# 93   https://www.mtgtop8.com/event?e=39049&d=491127&f=VI
# 94   https://www.mtgtop8.com/event?e=39049&d=491128&f=VI
# 95   https://www.mtgtop8.com/event?e=39049&d=491130&f=VI
# 96   https://www.mtgtop8.com/event?e=39049&d=491126&f=VI
# 97   https://www.mtgtop8.com/event?e=39049&d=491129&f=VI
# 98   https://www.mtgtop8.com/event?e=38912&d=490302&f=VI
# 99   https://www.mtgtop8.com/event?e=38912&d=490301&f=VI
# 100  https://www.mtgtop8.com/event?e=38912&d=490303&f=VI
# 101  https://www.mtgtop8.com/event?e=38912&d=490300&f=VI
# 102  https://www.mtgtop8.com/event?e=39344&d=492964&f=VI
# 103  https://www.mtgtop8.com/event?e=39344&d=492965&f=VI
# 104  https://www.mtgtop8.com/event?e=39344&d=492966&f=VI
# 105  https://www.mtgtop8.com/event?e=38709&d=488920&f=VI
# 106  https://www.mtgtop8.com/event?e=38709&d=488918&f=VI
# 107  https://www.mtgtop8.com/event?e=38709&d=488922&f=VI
# 108  https://www.mtgtop8.com/event?e=38709&d=488921&f=VI
# 109  https://www.mtgtop8.com/event?e=38709&d=488917&f=VI
# 110  https://www.mtgtop8.com/event?e=38709&d=488919&f=VI
# 111  https://www.mtgtop8.com/event?e=38709&d=488924&f=VI
# 112  https://www.mtgtop8.com/event?e=38709&d=488923&f=VI
# 113  https://www.mtgtop8.com/event?e=39196&d=492078&f=VI
# 114  https://www.mtgtop8.com/event?e=39196&d=492079&f=VI
# 115  https://www.mtgtop8.com/event?e=39196&d=492077&f=VI
# 116  https://www.mtgtop8.com/event?e=39196&d=492080&f=VI
# 117  https://www.mtgtop8.com/event?e=39390&d=493347&f=VI
# 118  https://www.mtgtop8.com/event?e=39390&d=493350&f=VI
# 119  https://www.mtgtop8.com/event?e=39390&d=493351&f=VI
# 120  https://www.mtgtop8.com/event?e=39390&d=493344&f=VI
# 121  https://www.mtgtop8.com/event?e=39390&d=493348&f=VI
# 122  https://www.mtgtop8.com/event?e=39390&d=493345&f=VI
# 123  https://www.mtgtop8.com/event?e=39390&d=493349&f=VI
# 124  https://www.mtgtop8.com/event?e=39390&d=493346&f=VI
# 125  https://www.mtgtop8.com/event?e=39443&d=493753&f=VI
# 126  https://www.mtgtop8.com/event?e=39443&d=493758&f=VI
# 127  https://www.mtgtop8.com/event?e=39443&d=493756&f=VI
# 128  https://www.mtgtop8.com/event?e=39443&d=493751&f=VI
# 129  https://www.mtgtop8.com/event?e=39443&d=493754&f=VI
# 130  https://www.mtgtop8.com/event?e=39443&d=493757&f=VI
# 131  https://www.mtgtop8.com/event?e=39443&d=493755&f=VI
# 132  https://www.mtgtop8.com/event?e=39443&d=493752&f=VI
# 133  https://www.mtgtop8.com/event?e=38567&d=488025&f=VI
# 134  https://www.mtgtop8.com/event?e=38567&d=488027&f=VI
# 135  https://www.mtgtop8.com/event?e=38567&d=488030&f=VI
# 136  https://www.mtgtop8.com/event?e=38567&d=488032&f=VI
# 137  https://www.mtgtop8.com/event?e=38567&d=488028&f=VI
# 138  https://www.mtgtop8.com/event?e=38567&d=488029&f=VI
# 139  https://www.mtgtop8.com/event?e=38567&d=488031&f=VI
# 140  https://www.mtgtop8.com/event?e=38567&d=488026&f=VI
# 141  https://www.mtgtop8.com/event?e=39455&d=493847&f=VI
# 142  https://www.mtgtop8.com/event?e=39455&d=493848&f=VI
# 143  https://www.mtgtop8.com/event?e=39455&d=493846&f=VI
# 144  https://www.mtgtop8.com/event?e=39455&d=493845&f=VI
# 145  https://www.mtgtop8.com/event?e=39202&d=492110&f=VI
# 146  https://www.mtgtop8.com/event?e=39202&d=492108&f=VI
# 147  https://www.mtgtop8.com/event?e=39202&d=492109&f=VI
# 148  https://www.mtgtop8.com/event?e=39202&d=492107&f=VI
# 149  https://www.mtgtop8.com/event?e=39445&d=493773&f=VI
# 150  https://www.mtgtop8.com/event?e=39445&d=493770&f=VI
# 151  https://www.mtgtop8.com/event?e=39445&d=493772&f=VI
# 152  https://www.mtgtop8.com/event?e=39445&d=493767&f=VI
# 153  https://www.mtgtop8.com/event?e=39445&d=493769&f=VI
# 154  https://www.mtgtop8.com/event?e=39445&d=493771&f=VI
# 155  https://www.mtgtop8.com/event?e=39445&d=493768&f=VI
# 156  https://www.mtgtop8.com/event?e=38274&d=486109&f=VI
# 157  https://www.mtgtop8.com/event?e=38274&d=486114&f=VI
# 158  https://www.mtgtop8.com/event?e=38274&d=486115&f=VI
# 159  https://www.mtgtop8.com/event?e=38274&d=486112&f=VI
# 160  https://www.mtgtop8.com/event?e=38274&d=486113&f=VI
# 161  https://www.mtgtop8.com/event?e=38274&d=486108&f=VI
# 162  https://www.mtgtop8.com/event?e=38274&d=486111&f=VI
# 163  https://www.mtgtop8.com/event?e=38274&d=486110&f=VI
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Deck list
# 0                                                                                                                                                                                                                                              1 Tinker\r\n1 Timetwister\r\n1 Force of Negation\r\n1 Demonic Tutor\r\n1 Time Walk\r\n1 Vampiric Tutor\r\n1 Mystical Tutor\r\n1 Mental Misstep\r\n1 Gitaxian Probe\r\n1 Brainstorm\r\n1 Ancestral Recall\r\n1 Narset, Parter of Veils\r\n1 Yawgmoth's Will\r\n1 Bolas's Citadel\r\n1 Soul-Guide Lantern\r\n1 Sensei's Divining Top\r\n1 Time Vault\r\n1 Sol Ring\r\n1 Mox Ruby\r\n1 Mox Pearl\r\n1 Mox Jet\r\n1 Mox Emerald\r\n1 Manifold Key\r\n1 Mana Crypt\r\n1 Black Lotus\r\n1 Lotus Petal\r\n1 Day's Undoing\r\n1 Mox Sapphire\r\n4 Flusterstorm\r\n4 Force of Will\r\n2 Sheoldred, the Apocalypse\r\n2 Opposition Agent\r\n4 Hullbreacher\r\n1 Polluted Delta\r\n1 Flooded Strand\r\n1 Misty Rainforest\r\n1 Tolarian Academy\r\n1 Island\r\n3 Scalding Tarn\r\n4 Urza's Saga\r\n4 Underground Sea\r\nSideboard\r\n1 Sphinx of the Steel Wind\r\n2 Pithing Needle\r\n4 Leyline of the Void\r\n4 Hurkyl's Recall\r\n2 Fatal Push\r\n2 Dismember\r\n
# 1                                                                                                                                                                                                                                                                        1 Manifold Key\r\n1 Mox Jet\r\n1 Mox Pearl\r\n1 Mox Ruby\r\n1 Mox Sapphire\r\n1 Sensei's Divining Top\r\n1 Sol Ring\r\n1 Time Vault\r\n1 Trinisphere\r\n1 Moonsilver Key\r\n1 Gerrard's Hourglass Pendant\r\n1 Pithing Needle\r\n1 Karn, the Great Creator\r\n1 Demonic Tutor\r\n1 Sea Gate Restoration\r\n1 Time Walk\r\n1 Tinker\r\n1 Ancestral Recall\r\n1 Black Lotus\r\n1 Mana Crypt\r\n1 Mox Emerald\r\n1 Mana Vault\r\n3 Mox Opal\r\n3 Grim Monolith\r\n4 Force of Will\r\n4 Paradoxical Outcome\r\n4 Coveted Jewel\r\n1 Cyberdrive Awakener\r\n2 Phyrexian Metamorph\r\n2 Hullbreacher\r\n2 Opposition Agent\r\n1 Tolarian Academy\r\n1 Otawara, Soaring City\r\n4 Ancient Tomb\r\n4 Mishra's Workshop\r\n4 Urza's Saga\r\nSideboard\r\n3 Leyline of the Void\r\n1 Tormod's Crypt\r\n1 Mycosynth Lattice\r\n3 Hurkyl's Recall\r\n2 Force of Negation\r\n3 Dismember\r\n1 Blightsteel Colossus\r\n1 Fractured Sanity\r\n
# 2                                                                                                                          1 Yawgmoth's Will\r\n1 Vampiric Tutor\r\n4 Urza's Saga\r\n2 Underground Sea\r\n2 Tundra\r\n1 Tolarian Academy\r\n1 Tinker\r\n1 Time Walk\r\n1 Time Vault\r\n1 Soul-Guide Lantern\r\n1 Sol Ring\r\n2 Snow-Covered Island\r\n1 Snapcaster Mage\r\n2 Sensei's Divining Top\r\n1 Scalding Tarn\r\n1 Repeal\r\n1 Ponder\r\n1 Polluted Delta\r\n1 Pithing Needle\r\n4 Paradoxical Outcome\r\n1 Narset, Parter of Veils\r\n1 Mystical Tutor\r\n1 Mox Sapphire\r\n1 Mox Ruby\r\n1 Mox Pearl\r\n2 Mox Opal\r\n1 Mox Jet\r\n1 Mox Emerald\r\n1 Monastery Mentor\r\n1 Misty Rainforest\r\n1 Merchant Scroll\r\n1 Mental Misstep\r\n1 Manifold Key\r\n1 Mana Vault\r\n1 Mana Crypt\r\n1 Hurkyl's Recall\r\n1 Gitaxian Probe\r\n4 Force of Will\r\n2 Flusterstorm\r\n1 Flooded Strand\r\n1 Demonic Tutor\r\n1 Brainstorm\r\n1 Bolas's Citadel\r\n1 Black Lotus\r\n1 Ancestral Recall\r\nSideboard\r\n3 Swords to Plowshares\r\n1 Sphinx of the Steel Wind\r\n1 Karn, the Great Creator\r\n1 Balance\r\n2 Soul-Guide Lantern\r\n2 Pithing Needle\r\n3 Hurkyl's Recall\r\n2 Flusterstorm\r\n
# 3                                                                                                                                                                                                       4 Ancient Tomb\r\n1 Black Lotus\r\n1 Chalice of the Void\r\n4 Crucible of Worlds\r\n4 Ghost Quarter\r\n1 God-Pharaoh's Statue\r\n4 Golos, Tireless Pilgrim\r\n1 Inventors' Fair\r\n1 Karakas\r\n1 Karn, the Great Creator\r\n1 Lodestone Golem\r\n1 Mana Crypt\r\n1 Mana Vault\r\n4 Mishra's Workshop\r\n1 Mox Emerald\r\n1 Mox Jet\r\n1 Mox Pearl\r\n1 Mox Ruby\r\n1 Mox Sapphire\r\n1 Mystic Forge\r\n1 Null Rod\r\n3 Phyrexian Revoker\r\n1 Pithing Needle\r\n1 Relic of Progenitus\r\n1 Sol Ring\r\n4 Sphere of Resistance\r\n1 Stonecoil Serpent\r\n1 Strip Mine\r\n1 The Tabernacle at Pendrell Vale\r\n1 Thorn of Amethyst\r\n1 Tolarian Academy\r\n1 Trinisphere\r\n4 Urza's Saga\r\n4 Wasteland\r\nSideboard\r\n2 Null Rod\r\n1 Relic of Progenitus\r\n1 The Tabernacle at Pendrell Vale\r\n1 Ensnaring Bridge\r\n1 Grafdigger's Cage\r\n1 Island\r\n1 Mental Misstep\r\n3 Mindbreak Trap\r\n1 Mycosynth Lattice\r\n1 Soul-Guide Lantern\r\n1 The Immortal Sun\r\n1 Wurmcoil Engine\r\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1 Mental Misstep\r\n1 Batterskull\r\n1 Black Lotus\r\n1 Kaldra Compleat\r\n1 Mana Crypt\r\n1 Mox Emerald\r\n1 Mox Jet\r\n1 Mox Pearl\r\n1 Mox Sapphire\r\n1 Mox Ruby\r\n2 Force of Vigor\r\n4 Once Upon a Time\r\n1 Thalia, Heretic Cathar\r\n1 Lion Sash\r\n4 Thalia, Guardian of Thraben\r\n4 Stoneforge Mystic\r\n4 Outland Liberator\r\n4 Noble Hierarch\r\n4 Luminarch Aspirant\r\n4 Archon of Emeria\r\n1 Strip Mine\r\n1 Plains\r\n1 Karakas\r\n3 Savannah\r\n4 Horizon Canopy\r\n4 Cavern of Souls\r\n4 Wasteland\r\nSideboard\r\n1 The Tabernacle at Pendrell Vale\r\n2 Mirran Crusader\r\n2 Mindbreak Trap\r\n3 Containment Priest\r\n4 Collector Ouphe\r\n1 Boseiju, Who Endures\r\n2 Force of Vigor\r\n
# 5                                                                                                                                                                           1 Bolas's Citadel\r\n1 Vampiric Tutor\r\n1 Mystical Tutor\r\n1 Mental Misstep\r\n1 Force of Negation\r\n1 Dig Through Time\r\n1 Brainstorm\r\n1 Ancestral Recall\r\n1 Abrade\r\n1 Treasure Cruise\r\n1 Tinker\r\n1 Time Walk\r\n1 Ponder\r\n1 Merchant Scroll\r\n1 Gitaxian Probe\r\n1 Demonic Tutor\r\n1 Dack Fayden\r\n1 Black Lotus\r\n1 Time Vault\r\n1 Sensei's Divining Top\r\n1 Pithing Needle\r\n1 Mox Sapphire\r\n1 Mox Ruby\r\n1 Mox Pearl\r\n1 Mox Jet\r\n1 Mox Emerald\r\n1 Manifold Key\r\n1 Narset, Parter of Veils\r\n1 Mana Crypt\r\n3 Flusterstorm\r\n3 Pyroblast\r\n4 Force of Will\r\n4 Ragavan, Nimble Pilferer\r\n1 Scalding Tarn\r\n2 Flooded Strand\r\n2 Misty Rainforest\r\n2 Polluted Delta\r\n2 Underground Sea\r\n4 Urza's Saga\r\n4 Volcanic Island\r\nSideboard\r\n2 The Tabernacle at Pendrell Vale\r\n1 Sphinx of the Steel Wind\r\n1 Shattering Spree\r\n1 Opposition Agent\r\n2 Lightning Bolt\r\n4 Leyline of the Void\r\n1 Alpine Moon\r\n1 Abrade\r\n1 Pithing Needle\r\n1 Pyroblast\r\n
# 6                                                                                                                                                     1 Bolas's Citadel\r\n1 Vampiric Tutor\r\n1 Mystical Tutor\r\n1 Mental Misstep\r\n1 Force of Negation\r\n1 Brainstorm\r\n1 Brain Freeze\r\n1 Ancestral Recall\r\n1 Abrade\r\n1 Tinker\r\n1 Time Walk\r\n1 Ponder\r\n1 Gitaxian Probe\r\n1 Demonic Tutor\r\n1 Dack Fayden\r\n1 Black Lotus\r\n1 Underworld Breach\r\n1 Time Vault\r\n1 Sol Ring\r\n1 Sensei's Divining Top\r\n1 Pithing Needle\r\n1 Mox Sapphire\r\n1 Mox Ruby\r\n1 Mox Pearl\r\n1 Mox Jet\r\n1 Mox Emerald\r\n1 Manifold Key\r\n1 Narset, Parter of Veils\r\n1 Mana Crypt\r\n2 Pyroblast\r\n3 Flusterstorm\r\n4 Force of Will\r\n1 Urza, Lord High Artificer\r\n1 Sphinx of the Steel Wind\r\n1 Opposition Agent\r\n3 Hullbreacher\r\n1 Tolarian Academy\r\n1 Island\r\n2 Scalding Tarn\r\n2 Underground Sea\r\n3 Misty Rainforest\r\n3 Volcanic Island\r\n4 Urza's Saga\r\nSideboard\r\n1 The Tabernacle at Pendrell Vale\r\n1 Soul-Guide Lantern\r\n2 Lightning Bolt\r\n4 Leyline of the Void\r\n2 By Force\r\n1 Alpine Moon\r\n1 Abrade\r\n2 Pyroblast\r\n1 Opposition Agent\r\n
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1 Gitaxian Probe\r\n1 Time Walk\r\n1 Ancestral Recall\r\n1 Mental Misstep\r\n1 Black Lotus\r\n1 Mana Crypt\r\n1 Mox Emerald\r\n1 Mox Pearl\r\n1 Mox Jet\r\n1 Mox Ruby\r\n1 Mox Sapphire\r\n1 Sol Ring\r\n2 Force of Negation\r\n2 Flusterstorm\r\n4 Force of Will\r\n1 True-Name Nemesis\r\n4 Silvergill Adept\r\n4 Thieving Skydiver\r\n4 Tide Shaper\r\n4 Vodalian Hexcatcher\r\n4 Hullbreacher\r\n1 Otawara, Soaring City\r\n1 Strip Mine\r\n4 Wasteland\r\n4 Cavern of Souls\r\n9 Island\r\nSideboard\r\n1 The Tabernacle at Pendrell Vale\r\n4 Surgical Extraction\r\n1 Pithing Needle\r\n1 Phantasmal Image\r\n2 Grafdigger's Cage\r\n4 Energy Flux\r\n1 Brazen Borrower\r\n1 Flusterstorm\r\n
# 8                                                                                                                                                     1 Bolas's Citadel\r\n1 Vampiric Tutor\r\n1 Mystical Tutor\r\n1 Mental Misstep\r\n1 Force of Negation\r\n1 Brainstorm\r\n1 Brain Freeze\r\n1 Ancestral Recall\r\n1 Abrade\r\n1 Tinker\r\n1 Time Walk\r\n1 Ponder\r\n1 Gitaxian Probe\r\n1 Demonic Tutor\r\n1 Dack Fayden\r\n1 Black Lotus\r\n1 Underworld Breach\r\n1 Time Vault\r\n1 Sol Ring\r\n1 Sensei's Divining Top\r\n1 Pithing Needle\r\n1 Mox Sapphire\r\n1 Mox Ruby\r\n1 Mox Pearl\r\n1 Mox Jet\r\n1 Mox Emerald\r\n1 Manifold Key\r\n1 Narset, Parter of Veils\r\n1 Mana Crypt\r\n2 Pyroblast\r\n3 Flusterstorm\r\n4 Force of Will\r\n1 Urza, Lord High Artificer\r\n1 Sphinx of the Steel Wind\r\n1 Opposition Agent\r\n3 Hullbreacher\r\n1 Tolarian Academy\r\n1 Island\r\n2 Scalding Tarn\r\n2 Underground Sea\r\n3 Misty Rainforest\r\n3 Volcanic Island\r\n4 Urza's Saga\r\nSideboard\r\n1 The Tabernacle at Pendrell Vale\r\n1 Soul-Guide Lantern\r\n2 Lightning Bolt\r\n4 Leyline of the Void\r\n2 By Force\r\n1 Alpine Moon\r\n1 Abrade\r\n2 Pyroblast\r\n1 Opposition Agent\r\n
# 9                                                                                                                                                            1 Narset, Parter of Veils\r\n1 Hullbreacher\r\n1 Demonic Tutor\r\n1 Gitaxian Probe\r\n1 Merchant Scroll\r\n1 Ponder\r\n1 Time Walk\r\n1 Tinker\r\n1 Yawgmoth's Will\r\n1 Ancestral Recall\r\n1 Brainstorm\r\n3 Flusterstorm\r\n1 Force of Negation\r\n4 Force of Will\r\n1 Hurkyl's Recall\r\n1 Mental Misstep\r\n4 Paradoxical Outcome\r\n3 Repeal\r\n1 Vampiric Tutor\r\n1 Black Lotus\r\n1 Bolas's Citadel\r\n1 Mana Crypt\r\n1 Mana Vault\r\n1 Manifold Key\r\n1 Mox Emerald\r\n1 Mox Jet\r\n2 Mox Opal\r\n1 Mox Pearl\r\n1 Mox Ruby\r\n1 Mox Sapphire\r\n1 Pithing Needle\r\n1 Sensei's Divining Top\r\n1 Sol Ring\r\n1 Time Vault\r\n1 Island\r\n4 Scalding Tarn\r\n1 Tolarian Academy\r\n2 Underground Sea\r\n4 Urza's Saga\r\n3 Volcanic Island\r\nSideboard\r\n1 Hurkyl's Recall\r\n1 Pithing Needle\r\n2 Abrade\r\n1 Lightning Bolt\r\n1 Mountain\r\n1 Nihil Spellbomb\r\n1 Opposition Agent\r\n2 Pyroblast\r\n1 Relic of Progenitus\r\n2 Shattering Spree\r\n1 Sphinx of the Steel Wind\r\n1 The Tabernacle at Pendrell Vale\r\n
# 10                                                                                                                           1 Dack Fayden\r\n1 Narset, Parter of Veils\r\n4 Hullbreacher\r\n1 Demonic Tutor\r\n1 Gitaxian Probe\r\n1 Merchant Scroll\r\n1 Ponder\r\n1 Time Walk\r\n1 Timetwister\r\n1 Tinker\r\n1 Abrade\r\n1 Ancestral Recall\r\n1 Brain Freeze\r\n1 Brainstorm\r\n1 Dig Through Time\r\n2 Flusterstorm\r\n4 Force of Will\r\n1 Mental Misstep\r\n1 Mystical Tutor\r\n1 Pyroblast\r\n1 Vampiric Tutor\r\n1 Black Lotus\r\n1 Bolas's Citadel\r\n1 Mana Crypt\r\n1 Manifold Key\r\n1 Mox Emerald\r\n1 Mox Jet\r\n1 Mox Pearl\r\n1 Mox Ruby\r\n1 Mox Sapphire\r\n1 Pithing Needle\r\n1 Sensei's Divining Top\r\n1 Sol Ring\r\n1 Time Vault\r\n2 Underworld Breach\r\n2 Flooded Strand\r\n1 Island\r\n2 Misty Rainforest\r\n1 Polluted Delta\r\n1 Scalding Tarn\r\n1 Tolarian Academy\r\n2 Underground Sea\r\n4 Urza's Saga\r\n3 Volcanic Island\r\nSideboard\r\n1 Flusterstorm\r\n2 Pyroblast\r\n1 Pithing Needle\r\n1 Alpine Moon\r\n1 By Force\r\n2 Hurkyl's Recall\r\n4 Leyline of the Void\r\n1 Lightning Bolt\r\n1 Sphinx of the Steel Wind\r\n1 The Tabernacle at Pendrell Vale\r\n
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1 Mental Misstep\r\n1 Black Lotus\r\n1 Mox Emerald\r\n1 Mox Jet\r\n2 Once Upon a Time\r\n3 Force of Vigor\r\n4 Serum Powder\r\n2 Stitcher's Supplier\r\n4 Deathrite Shaman\r\n4 Bloodghast\r\n4 Basking Rootwalla\r\n4 Hogaak, Arisen Necropolis\r\n4 Hollow One\r\n4 Vengevine\r\n4 Blazing Rootwalla\r\n1 Wooded Foothills\r\n1 Taiga\r\n1 Strip Mine\r\n1 Dryad Arbor\r\n1 Boseiju, Who Endures\r\n1 Bayou\r\n1 Badlands\r\n2 Verdant Catacombs\r\n4 Bazaar of Baghdad\r\n4 Wasteland\r\nSideboard\r\n2 Pyroblast\r\n4 Leyline of the Void\r\n4 Collector Ouphe\r\n3 Archive Trap\r\n1 Force of Vigor\r\n1 Boseiju, Who Endures\r\n
# 12                                                                                                                                                                                                                                                                                     4 Ancient Tomb\r\n1 Black Lotus\r\n1 Chalice of the Void\r\n3 Crucible of Worlds\r\n2 Ghost Quarter\r\n4 Golos, Tireless Pilgrim\r\n1 Inventors' Fair\r\n1 Karakas\r\n1 Karn, the Great Creator\r\n1 Lodestone Golem\r\n1 Mana Crypt\r\n1 Mana Vault\r\n1 Manifold Key\r\n4 Mishra's Workshop\r\n1 Mox Emerald\r\n1 Mox Jet\r\n1 Mox Pearl\r\n1 Mox Ruby\r\n1 Mox Sapphire\r\n1 Mystic Forge\r\n2 Nettlecyst\r\n4 Phyrexian Revoker\r\n1 Pithing Needle\r\n1 Sol Ring\r\n2 Sorcerous Spyglass\r\n4 Sphere of Resistance\r\n1 Strip Mine\r\n1 The Tabernacle at Pendrell Vale\r\n1 Thorn of Amethyst\r\n1 Time Vault\r\n1 Tolarian Academy\r\n1 Trinisphere\r\n4 Urza's Saga\r\n4 Wasteland\r\nSideboard\r\n1 The Tabernacle at Pendrell Vale\r\n2 Archive Trap\r\n1 Ensnaring Bridge\r\n2 Grafdigger's Cage\r\n1 Mental Misstep\r\n2 Mindbreak Trap\r\n1 Mycosynth Lattice\r\n3 Null Rod\r\n2 Wurmcoil Engine\r\n
# 13                                                                                                                                                                                                                                                                                      1 Island\r\n1 Misty Rainforest\r\n1 Polluted Delta\r\n4 Scalding Tarn\r\n1 Strip Mine\r\n3 Tundra\r\n3 Volcanic Island\r\n3 Wasteland\r\n2 Dreadhorde Arcanist\r\n1 Lavinia, Azorius Renegade\r\n1 Monastery Mentor\r\n3 Ragavan, Nimble Pilferer\r\n1 Ancestral Recall\r\n1 Brainstorm\r\n1 Daze\r\n1 Dig Through Time\r\n2 Flusterstorm\r\n1 Force of Negation\r\n4 Force of Will\r\n1 Gitaxian Probe\r\n1 Gush\r\n1 Mental Misstep\r\n1 Merchant Scroll\r\n1 Ponder\r\n4 Preordain\r\n2 Prismatic Ending\r\n3 Pyroblast\r\n2 Swords to Plowshares\r\n1 Time Walk\r\n1 Treasure Cruise\r\n1 Black Lotus\r\n2 Dack Fayden\r\n1 Mox Pearl\r\n1 Mox Ruby\r\n1 Mox Sapphire\r\n1 Narset, Parter of Veils\r\nSideboard\r\n1 Wasteland\r\n1 Prismatic Ending\r\n1 Swords to Plowshares\r\n4 Leyline of the Void\r\n1 Mindbreak Trap\r\n1 Mountain\r\n3 Shattering Spree\r\n1 Young Pyromancer\r\n2 Stony Silence\r\n
# 14                                                                                                                                                                                                                                                                                                                                                                                                                             2 Goblin Charbelcher\r\n4 Force of Will\r\n1 Dread Return\r\n4 Balustrade Spy\r\n4 Sea Gate Restoration\r\n4 Agadeem's Awakening\r\n4 Dark Ritual\r\n4 Undercity Informer\r\n1 Tinker\r\n1 Thassa's Oracle\r\n4 Pact of Negation\r\n4 Narcomoeba\r\n2 Cabal Therapy\r\n1 Mana Crypt\r\n1 Black Lotus\r\n1 Sol Ring\r\n1 Mox Pearl\r\n1 Mox Jet\r\n1 Mox Sapphire\r\n1 Mox Emerald\r\n1 Mox Ruby\r\n1 Demonic Tutor\r\n1 Ancestral Recall\r\n1 Mental Misstep\r\n1 Gitaxian Probe\r\n1 Chain of Vapor\r\n1 Lotus Petal\r\n1 Mana Vault\r\n4 Chrome Mox\r\n1 Lion's Eye Diamond\r\n1 Vampiric Tutor\r\nSideboard\r\n2 Goblin Charbelcher\r\n3 Chain of Vapor\r\n3 Leyline of the Void\r\n1 Blightsteel Colossus\r\n3 Force of Negation\r\n2 Grief\r\n1 Opposition Agent\r\n
# 15                                                                                                                                                                                                                     1 Mystical Tutor\r\n1 Brainstorm\r\n1 Ponder\r\n1 Gitaxian Probe\r\n1 Ancestral Recall\r\n1 Mana Crypt\r\n1 Black Lotus\r\n1 Mox Pearl\r\n1 Mox Ruby\r\n1 Mox Jet\r\n1 Mox Sapphire\r\n1 Mox Emerald\r\n1 Mental Misstep\r\n1 Pyroblast\r\n1 Dress Down\r\n1 Fire / Ice\r\n1 Gush\r\n1 Force of Negation\r\n1 Dig Through Time\r\n1 Treasure Cruise\r\n1 Time Walk\r\n2 Lightning Bolt\r\n2 Flusterstorm\r\n3 Preordain\r\n4 Force of Will\r\n4 Fable of the Mirror-Breaker\r\n1 Hullbreacher\r\n1 Fury\r\n3 Ledger Shredder\r\n4 Caves of Chaos Adventurer\r\n1 Strip Mine\r\n1 Misty Rainforest\r\n1 Flooded Strand\r\n1 Scalding Tarn\r\n2 Island\r\n2 Polluted Delta\r\n3 Wasteland\r\n4 Volcanic Island\r\nSideboard\r\n3 Shattering Spree\r\n1 Blue Elemental Blast\r\n1 Pithing Needle\r\n2 Soul-Guide Lantern\r\n1 Sphinx of the Steel Wind\r\n1 Tinker\r\n2 Surgical Extraction\r\n1 The Tabernacle at Pendrell Vale\r\n1 Lightning Bolt\r\n1 Flusterstorm\r\n1 Fury\r\n
# 16                                                                                                                                                                        1 Merchant Scroll\r\n1 Tolarian Academy\r\n2 Polluted Delta\r\n3 Sensei's Divining Top\r\n1 Black Lotus\r\n1 Mox Ruby\r\n3 Island\r\n1 Ponder\r\n1 Ancestral Recall\r\n2 Misty Rainforest\r\n2 Underground Sea\r\n1 Snapcaster Mage\r\n1 Repeal\r\n1 Flooded Strand\r\n1 Monastery Mentor\r\n1 Narset, Parter of Veils\r\n1 Yawgmoth's Will\r\n2 Dress Down\r\n4 Paradoxical Outcome\r\n1 Brainstorm\r\n1 Time Walk\r\n1 Tundra\r\n1 Mox Emerald\r\n1 Mox Jet\r\n1 Hurkyl's Recall\r\n1 Scalding Tarn\r\n1 Mox Pearl\r\n1 Mystical Tutor\r\n1 Mental Misstep\r\n3 Flusterstorm\r\n4 Force of Will\r\n1 Teferi, Time Raveler\r\n1 Vampiric Tutor\r\n1 Demonic Tutor\r\n3 Mox Opal\r\n1 Gitaxian Probe\r\n1 Bolas's Citadel\r\n1 Tinker\r\n1 Sol Ring\r\n1 Mana Crypt\r\n1 Mana Vault\r\n1 Mox Sapphire\r\nSideboard\r\n1 Pithing Needle\r\n2 Tormod's Crypt\r\n1 Toxic Deluge\r\n2 The Tabernacle at Pendrell Vale\r\n1 Sphinx of the Steel Wind\r\n2 Opposition Agent\r\n2 Cut Down\r\n3 Hurkyl's Recall\r\n1 Flusterstorm\r\n
# 17                                                                                                                                                                                                                                                                                                                                                                                              1 Mox Ruby\r\n1 Black Lotus\r\n1 Time Walk\r\n1 Mox Pearl\r\n1 Brainstorm\r\n1 Treasure Cruise\r\n1 Gush\r\n1 Mox Jet\r\n1 Mana Crypt\r\n1 Ponder\r\n1 Mox Emerald\r\n1 Dig Through Time\r\n1 Mental Misstep\r\n1 Bolas's Citadel\r\n1 Force of Negation\r\n1 Mox Sapphire\r\n1 Ancestral Recall\r\n1 Tinker\r\n1 Gitaxian Probe\r\n1 Sol Ring\r\n2 Flusterstorm\r\n4 Force of Will\r\n4 Preordain\r\n4 Fable of the Mirror-Breaker\r\n1 Sphinx of the Steel Wind\r\n4 Magus of the Moon\r\n4 Caves of Chaos Adventurer\r\n4 Ledger Shredder\r\n1 Misty Rainforest\r\n1 Polluted Delta\r\n1 Mountain\r\n3 Volcanic Island\r\n3 Island\r\n4 Scalding Tarn\r\nSideboard\r\n3 Fury\r\n2 Pyroblast\r\n4 Leyline of the Void\r\n1 The Tabernacle at Pendrell Vale\r\n3 Shattering Spree\r\n2 Hullbreacher\r\n
# ...
# 151                                                                                                                                                                                                                                                                                  3 Swords to Plowshares\r\n2 Underworld Breach\r\n1 Merchant Scroll\r\n1 Mox Sapphire\r\n1 Brainstorm\r\n1 Force of Negation\r\n4 Preordain\r\n1 Mox Pearl\r\n1 Dig Through Time\r\n4 Mishra's Bauble\r\n2 Flooded Strand\r\n1 Strip Mine\r\n1 Brain Freeze\r\n3 Dreadhorde Arcanist\r\n1 Time Walk\r\n2 Misty Rainforest\r\n2 Pyroblast\r\n2 Tundra\r\n1 Ponder\r\n3 Wasteland\r\n1 Flusterstorm\r\n1 Gitaxian Probe\r\n1 Mystical Tutor\r\n1 Mox Ruby\r\n3 Expressive Iteration\r\n4 Volcanic Island\r\n2 Ragavan, Nimble Pilferer\r\n2 Scalding Tarn\r\n1 Ancestral Recall\r\n4 Force of Will\r\n1 Polluted Delta\r\n1 Mental Misstep\r\n1 Black Lotus\r\nSideboard\r\n1 Swords to Plowshares\r\n1 Force of Negation\r\n1 Pyroblast\r\n1 Wasteland\r\n2 Prismatic Ending\r\n1 Lurrus of the Dream-Den\r\n3 Tormod's Crypt\r\n1 Red Elemental Blast\r\n3 Shattering Spree\r\n1 The Tabernacle at Pendrell Vale\r\n
# 152                                                                                                                                                                                                                                                                                                          1 Sea Gate Restoration\r\n1 Sensei's Divining Top\r\n1 Time Vault\r\n1 Black Lotus\r\n1 Prophetic Prism\r\n1 Mox Emerald\r\n1 Time Walk\r\n1 Mystic Forge\r\n1 Mox Pearl\r\n1 Trinisphere\r\n1 Tinker\r\n1 Mana Vault\r\n1 Mox Jet\r\n1 Sol Ring\r\n1 Mox Sapphire\r\n1 Karn, the Great Creator\r\n1 Demonic Tutor\r\n1 Mana Crypt\r\n1 Mox Ruby\r\n1 Manifold Key\r\n1 Ancestral Recall\r\n2 The Antiquities War\r\n3 Mox Opal\r\n4 Force of Will\r\n4 Coveted Jewel\r\n4 Paradoxical Outcome\r\n4 Grim Monolith\r\n1 Blightsteel Colossus\r\n4 Phyrexian Metamorph\r\n1 Tolarian Academy\r\n4 Urza's Saga\r\n4 Mishra's Workshop\r\n4 Ancient Tomb\r\nSideboard\r\n1 Slaughter Pact\r\n1 Defense Grid\r\n1 Grafdigger's Cage\r\n1 Mycosynth Lattice\r\n1 Sphinx of the Steel Wind\r\n4 Hurkyl's Recall\r\n1 Soul-Guide Lantern\r\n3 Dismember\r\n1 Tormod's Crypt\r\n1 Pithing Needle\r\n
# 153                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               4 Hollow One\r\n4 Force of Vigor\r\n2 Golgari Thug\r\n4 Serum Powder\r\n4 Bazaar of Baghdad\r\n3 Dakmor Salvage\r\n4 Ichorid\r\n4 Force of Will\r\n1 Golgari Grave-Troll\r\n4 Grief\r\n4 Creeping Chill\r\n4 Narcomoeba\r\n1 Noxious Revival\r\n1 Mental Misstep\r\n4 Bloodghast\r\n4 Stinkweed Imp\r\n4 Prized Amalgam\r\n4 Shambling Shell\r\nSideboard\r\n3 Noxious Revival\r\n4 Leyline of the Void\r\n1 Chalice of the Void\r\n1 Mindbreak Trap\r\n3 Wasteland\r\n2 Contagion\r\n1 Strip Mine\r\n
# 154                                                                                                                                                                                                                                                                                                                                                                                                                                                  1 Mana Vault\r\n4 Wasteland\r\n4 Walking Ballista\r\n4 Sphere of Resistance\r\n4 Mishra's Workshop\r\n1 Mana Crypt\r\n1 Mox Pearl\r\n4 Ancient Tomb\r\n1 Mox Emerald\r\n1 Mox Jet\r\n1 Lodestone Golem\r\n1 Strip Mine\r\n1 Mox Ruby\r\n4 Urza's Saga\r\n1 Sol Ring\r\n4 Phyrexian Revoker\r\n1 Black Lotus\r\n1 Gingerbrute\r\n1 Trinisphere\r\n4 Foundry Inspector\r\n4 Patchwork Automaton\r\n1 Mox Sapphire\r\n1 Chalice of the Void\r\n1 Tolarian Academy\r\n4 Arcbound Ravager\r\n4 Nettlecyst\r\n1 Thorn of Amethyst\r\nSideboard\r\n2 Wurmcoil Engine\r\n1 Crucible of Worlds\r\n3 Grafdigger's Cage\r\n1 Mental Misstep\r\n1 Skysovereign, Consul Flagship\r\n2 Archive Trap\r\n1 Soul-Guide Lantern\r\n1 Pithing Needle\r\n3 Null Rod\r\n
# 155                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1 Golgari Grave-Troll\r\n4 Silversmote Ghoul\r\n2 Force of Vigor\r\n4 Golgari Thug\r\n4 Bazaar of Baghdad\r\n1 Mental Misstep\r\n4 Shambling Shell\r\n4 Hollow One\r\n4 Grief\r\n2 Noxious Revival\r\n4 Ichorid\r\n4 Force of Will\r\n4 Stinkweed Imp\r\n4 Serum Powder\r\n4 Narcomoeba\r\n2 Force of Negation\r\n4 Prized Amalgam\r\n4 Creeping Chill\r\nSideboard\r\n2 Force of Vigor\r\n2 Noxious Revival\r\n3 Wasteland\r\n4 Leyline of the Void\r\n2 Contagion\r\n1 Strip Mine\r\n1 Mindbreak Trap\r\n
# 156                                                                                                                                                                        1 Black Lotus\r\n1 Pithing Needle\r\n1 Mental Misstep\r\n3 Island\r\n1 Ancestral Recall\r\n1 Tolarian Academy\r\n1 Misty Rainforest\r\n1 Time Walk\r\n1 Mana Vault\r\n1 Merchant Scroll\r\n1 Gitaxian Probe\r\n1 Sol Ring\r\n1 Repeal\r\n1 Bolas's Citadel\r\n1 Time Vault\r\n1 Demonic Tutor\r\n1 Narset, Parter of Veils\r\n1 Mox Ruby\r\n1 Mox Pearl\r\n1 Mox Jet\r\n1 Mox Emerald\r\n1 Ponder\r\n1 Mox Sapphire\r\n4 Paradoxical Outcome\r\n1 Tinker\r\n1 Yawgmoth's Will\r\n1 Brainstorm\r\n4 Urza's Saga\r\n1 Vampiric Tutor\r\n1 Mystical Tutor\r\n1 Mana Crypt\r\n1 Hurkyl's Recall\r\n1 Manifold Key\r\n1 Polluted Delta\r\n3 Underground Sea\r\n1 Sphinx of the Steel Wind\r\n2 Sensei's Divining Top\r\n4 Flusterstorm\r\n1 Flooded Strand\r\n1 Scalding Tarn\r\n4 Force of Will\r\n2 Mox Opal\r\nSideboard\r\n2 Pithing Needle\r\n3 Hurkyl's Recall\r\n1 Opposition Agent\r\n2 The Tabernacle at Pendrell Vale\r\n1 Soul-Guide Lantern\r\n1 Tormod's Crypt\r\n1 Ravenous Trap\r\n2 Hullbreacher\r\n2 Cut Down\r\n
# 157                                                                                                                                                                   4 Underworld Breach\r\n3 Brain Freeze\r\n1 Demonic Tutor\r\n1 Vampiric Tutor\r\n1 Time Vault\r\n1 Manifold Key\r\n4 Urza's Saga\r\n1 Ancestral Recall\r\n1 Time Walk\r\n1 Brainstorm\r\n1 Ponder\r\n4 Preordain\r\n4 Force of Will\r\n2 Pact of Negation\r\n1 Force of Negation\r\n1 Mental Misstep\r\n1 Merchant Scroll\r\n1 Gitaxian Probe\r\n1 Tinker\r\n1 Chain of Vapor\r\n1 Hurkyl's Recall\r\n1 Lightning Bolt\r\n2 Street Wraith\r\n1 Paradoxical Outcome\r\n1 Mox Jet\r\n1 Mox Sapphire\r\n1 Mox Pearl\r\n1 Mox Emerald\r\n1 Mox Ruby\r\n1 Lotus Petal\r\n1 Black Lotus\r\n1 Mana Crypt\r\n1 Sol Ring\r\n1 Island\r\n3 Volcanic Island\r\n2 Underground Sea\r\n3 Scalding Tarn\r\n2 Flooded Strand\r\nSideboard\r\n1 Hurkyl's Recall\r\n2 Ravenous Trap\r\n2 Nihil Spellbomb\r\n1 The Tabernacle at Pendrell Vale\r\n1 Dismember\r\n1 Rack and Ruin\r\n1 Blightsteel Colossus\r\n1 Bolas's Citadel\r\n1 Thoughtseize\r\n1 Red Elemental Blast\r\n1 Opposition Agent\r\n1 Laelia, the Blade Reforged\r\n1 Hullbreacher\r\n
# 158                                                                                                                                                                                                                                                  3 Wasteland\r\n1 Sylvan Library\r\n1 Force of Negation\r\n1 Boseiju, Who Endures\r\n3 Tropical Island\r\n1 Time Walk\r\n2 Oko, Thief of Crowns\r\n1 Strip Mine\r\n1 Mox Sapphire\r\n1 Mox Ruby\r\n1 Mox Emerald\r\n1 Mental Misstep\r\n3 Misty Rainforest\r\n4 Force of Will\r\n3 Pyroblast\r\n2 Lightning Bolt\r\n3 Ragavan, Nimble Pilferer\r\n2 Outland Liberator\r\n3 Scalding Tarn\r\n1 Ponder\r\n1 Black Lotus\r\n1 Ancestral Recall\r\n2 Minsc & Boo, Timeless Heroes\r\n1 Brainstorm\r\n3 Volcanic Island\r\n3 Wrenn and Six\r\n1 Narset, Parter of Veils\r\n2 Flusterstorm\r\n1 Gitaxian Probe\r\n2 Force of Vigor\r\n1 Treasure Cruise\r\n1 Merchant Scroll\r\n3 Collector Ouphe\r\nSideboard\r\n1 Boseiju, Who Endures\r\n1 Pyroblast\r\n1 Lightning Bolt\r\n1 Flusterstorm\r\n1 Force of Vigor\r\n1 Collector Ouphe\r\n2 Energy Flux\r\n1 Pithing Needle\r\n1 Grafdigger's Cage\r\n1 The Tabernacle at Pendrell Vale\r\n4 Endurance\r\n
# 159                                                                                                                                                                                                                                                                                                                                                                                                                       4 Preordain\r\n1 Gitaxian Probe\r\n1 Ponder\r\n1 Brainstorm\r\n1 Sensei's Divining Top\r\n4 Street Wraith\r\n4 Flusterstorm\r\n4 Force of Will\r\n1 Mental Misstep\r\n1 Thoughtseize\r\n1 Daze\r\n3 Scalding Tarn\r\n3 Flooded Strand\r\n3 Polluted Delta\r\n4 Underground Sea\r\n1 Island\r\n1 Lotus Petal\r\n1 Mox Jet\r\n1 Mox Sapphire\r\n1 Black Lotus\r\n1 Vampiric Tutor\r\n1 Demonic Consultation\r\n1 Mystical Tutor\r\n1 Gush\r\n1 Demonic Tutor\r\n1 Necropotence\r\n1 Dig Through Time\r\n1 Time Walk\r\n1 Ancestral Recall\r\n4 Doomsday\r\n4 Dark Ritual\r\n2 Thassa's Oracle\r\nSideboard\r\n1 Island\r\n4 Steel Sabotage\r\n4 Leyline of the Void\r\n1 Grafdigger's Cage\r\n2 Fatal Push\r\n1 Murktide Regent\r\n1 Opposition Agent\r\n1 Force of Negation\r\n
# 160                                                                                                                                                                                                                                              1 Black Lotus\r\n1 Bolas's Citadel\r\n1 Lotus Petal\r\n1 Mana Crypt\r\n1 Mox Emerald\r\n1 Mox Jet\r\n1 Mox Ruby\r\n1 Mox Sapphire\r\n1 Sensei's Divining Top\r\n1 Blightsteel Colossus\r\n3 Underworld Breach\r\n1 Ancestral Recall\r\n2 Brain Freeze\r\n1 Brainstorm\r\n3 Flusterstorm\r\n1 Force of Negation\r\n4 Force of Will\r\n1 Lightning Bolt\r\n1 Mental Misstep\r\n1 Mystical Tutor\r\n3 Pyroblast\r\n1 Vampiric Tutor\r\n2 Flooded Strand\r\n1 Island\r\n3 Scalding Tarn\r\n3 Underground Sea\r\n4 Urza's Saga\r\n4 Volcanic Island\r\n1 Dack Fayden\r\n1 Narset, Parter of Veils\r\n1 Demonic Tutor\r\n1 Merchant Scroll\r\n1 Ponder\r\n3 Preordain\r\n1 Time Walk\r\n1 Tinker\r\n1 Gitaxian Probe\r\nSideboard\r\n1 Pithing Needle\r\n2 Alpine Moon\r\n4 Leyline of the Void\r\n1 Red Elemental Blast\r\n1 Abrade\r\n3 Shattering Spree\r\n1 Subterranean Tremors\r\n1 Laelia, the Blade Reforged\r\n1 The Tabernacle at Pendrell Vale\r\n
# 161                                                                                                                                                         1 Narset, Parter of Veils\r\n1 Monastery Mentor\r\n1 Snapcaster Mage\r\n1 Demonic Tutor\r\n1 Gitaxian Probe\r\n1 Merchant Scroll\r\n1 Ponder\r\n1 Time Walk\r\n1 Tinker\r\n1 Yawgmoth's Will\r\n1 Ancestral Recall\r\n1 Brainstorm\r\n2 Flusterstorm\r\n4 Force of Will\r\n1 Hurkyl's Recall\r\n1 Mental Misstep\r\n1 Mystical Tutor\r\n4 Paradoxical Outcome\r\n1 Repeal\r\n1 Vampiric Tutor\r\n1 Black Lotus\r\n1 Bolas's Citadel\r\n1 Mana Crypt\r\n1 Mana Vault\r\n1 Manifold Key\r\n1 Mox Emerald\r\n1 Mox Jet\r\n2 Mox Opal\r\n1 Mox Pearl\r\n1 Mox Ruby\r\n1 Mox Sapphire\r\n1 Pithing Needle\r\n2 Sensei's Divining Top\r\n1 Sol Ring\r\n1 Soul-Guide Lantern\r\n1 Time Vault\r\n1 Flooded Strand\r\n1 Misty Rainforest\r\n2 Scalding Tarn\r\n2 Island\r\n1 Tolarian Academy\r\n2 Tundra\r\n2 Underground Sea\r\n4 Urza's Saga\r\nSideboard\r\n2 Flusterstorm\r\n3 Hurkyl's Recall\r\n2 Pithing Needle\r\n2 Soul-Guide Lantern\r\n1 Balance\r\n1 Karn, the Great Creator\r\n1 Sphinx of the Steel Wind\r\n3 Swords to Plowshares\r\n
# 162                                                                                                                                                                                                                                                                              1 Boseiju, Who Endures\r\n1 Forest\r\n3 Misty Rainforest\r\n1 Strip Mine\r\n3 Tropical Island\r\n3 Underground Sea\r\n3 Verdant Catacombs\r\n4 Wasteland\r\n3 Collector Ouphe\r\n4 Deathrite Shaman\r\n2 Endurance\r\n2 Leovold, Emissary of Trest\r\n2 Tarmogoyf\r\n1 Ancestral Recall\r\n3 Assassin's Trophy\r\n1 Brainstorm\r\n3 Daze\r\n1 Demonic Tutor\r\n1 Dig Through Time\r\n1 Flusterstorm\r\n1 Force of Vigor\r\n4 Force of Will\r\n1 Mental Misstep\r\n1 Ponder\r\n1 Time Walk\r\n1 Treasure Cruise\r\n1 Black Lotus\r\n1 Mox Emerald\r\n1 Mox Jet\r\n1 Mox Sapphire\r\n1 Narset, Parter of Veils\r\n2 Oko, Thief of Crowns\r\n1 Sylvan Library\r\nSideboard\r\n1 Boseiju, Who Endures\r\n1 Collector Ouphe\r\n2 Endurance\r\n1 Assassin's Trophy\r\n2 Flusterstorm\r\n2 Force of Vigor\r\n1 Energy Flux\r\n1 Fatal Push\r\n1 Surgical Extraction\r\n2 The Tabernacle at Pendrell Vale\r\n1 Toxic Deluge\r\n
# 163                                                                                                                                                                                                                                                 1 Mox Sapphire\r\n1 Mox Ruby\r\n1 Mox Pearl\r\n1 Merchant Scroll\r\n1 Mental Misstep\r\n1 Gitaxian Probe\r\n1 Gush\r\n1 Dig Through Time\r\n1 Brainstorm\r\n1 Ancestral Recall\r\n1 Mystical Tutor\r\n1 Ponder\r\n1 Black Lotus\r\n1 Time Walk\r\n1 Treasure Cruise\r\n2 Prismatic Ending\r\n2 Swords to Plowshares\r\n2 Force of Negation\r\n2 Expressive Iteration\r\n4 Force of Will\r\n4 Mishra's Bauble\r\n4 Preordain\r\n1 Jace, Vryn's Prodigy\r\n2 Dreadhorde Arcanist\r\n2 Lavinia, Azorius Renegade\r\n3 Ragavan, Nimble Pilferer\r\n1 Polluted Delta\r\n1 Strip Mine\r\n2 Misty Rainforest\r\n2 Scalding Tarn\r\n2 Flooded Strand\r\n3 Volcanic Island\r\n3 Tundra\r\n3 Wasteland\r\nSideboard\r\n1 Pithing Needle\r\n1 Soul-Guide Lantern\r\n1 The Tabernacle at Pendrell Vale\r\n3 Shattering Spree\r\n1 Surgical Extraction\r\n3 Pyroblast\r\n1 Lurrus of the Dream-Den\r\n1 Flusterstorm\r\n2 Swords to Plowshares\r\n1 Wasteland\r\n
